# %%
import pandas as pd

# %%
movies = pd.read_csv('movies_1.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631 entries, 0 to 630
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           631 non-null    object
#  1   name         631 non-null    object
#  2   rating       626 non-null    float64
#  3   ratingCount  631 non-null    int64
#  4   movieRank    631 non-null    int64
#  5   genres       631 non-null    object
#  6   duration     250 non-null    object
#  7   seconds      618 non-null    float64
#  8   description  627 non-null    object
#  9   releaseYear  626 non-null    float64
#  10  countries    630 non-null    object
#  11  directors    631 non-null    object
#  12  casts        631 non-null    object
#  13  suggestions  625 non-null    object
#  14  keywords     631 non-null    object
#  15  quotes       631 non-null    object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 79.0+ KB

# %%
movies['userRate'] = [None for _ in range(movies.shape[0])]

# %%
movies.shape[0]
# Out:
# 631

# %%
# Out:
#              id                             name  rating  ratingCount  \
# 0     tt0111161         The Shawshank Redemption     9.3      2984875
# 1     tt0068646                    The Godfather     9.2      2083022
# 2     tt0468569                  The Dark Knight     9.0      2965241
# 3     tt0071562            The Godfather Part II     9.0      1405158
# 4     tt0050083                     12 Angry Men     9.0       902739
# ..          ...                              ...     ...          ...
# 626   tt3895150                Your Lie in April     8.5        41318
# 627   tt5249462                           Erased     8.4        63082
# 628   tt2061702  To the Forest of Firefly Lights     7.8        22912
# 629   tt8207132                   A Silent Voice     6.5           29
# 630  tt12879624    Josee, the Tiger and the Fish     7.6         9027
#
#      movieRank                             genres duration  seconds  \
# ...
