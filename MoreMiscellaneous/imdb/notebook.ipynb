# %%
import pandas as pd

# %%
import json

# %%
top250 = pd.read_csv('top250_1.csv')
suggested_by250 = pd.read_csv('suggested_by250_1.csv')

# %%
top250[top250['suggestions'].isnull()]
# Out:
#     Unnamed: 0         id                      name  rating  ratingCount  \
# 87          88  tt0045152  Singin&apos; in the Rain     8.3       268472
#
#     movieRank                            genres duration  seconds  \
# 87          0  ['Comedy', 'Musical', 'Romance']    1H43M     6180
#
#                                           description  releaseYear  \
# 87  A silent film star falls for a chorus girl jus...         1952
#
#             countries                        directors  \
# 87  ['United States']  ['Stanley Donen', 'Gene Kelly']
#
#                                                 casts suggestions  \
# 87  ['Gene Kelly', "Donald O'Connor", 'Debbie Reyn...         NaN
#
#                                              keywords  \
# 87  ['movie studio', 'film within a film', 'tap da...
#
#                                                quotes
# 87  ["Lina. She can't act, she can't sing, she can...

# %%
movies = pd.concat([top250, suggested_by250])

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 641 entries, 0 to 390
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   641 non-null    int64
#  1   id           641 non-null    object
#  2   name         641 non-null    object
#  3   rating       635 non-null    float64
#  4   ratingCount  641 non-null    int64
#  5   movieRank    641 non-null    int64
#  6   genres       641 non-null    object
#  7   duration     250 non-null    object
#  8   seconds      628 non-null    float64
#  9   description  638 non-null    object
#  10  releaseYear  636 non-null    float64
#  11  countries    640 non-null    object
#  12  directors    641 non-null    object
#  13  casts        641 non-null    object
#  14  suggestions  634 non-null    object
#  15  keywords     641 non-null    object
#  16  quotes       641 non-null    object
# dtypes: float64(3), int64(3), object(11)
# memory usage: 90.1+ KB

# %%
movies.head()
# Out:
#    Unnamed: 0         id                      name  rating  ratingCount  \
# 0           1  tt0111161  The Shawshank Redemption     9.3      2984193
# 1           2  tt0068646             The Godfather     9.2      2082354
# 2           3  tt0468569           The Dark Knight     9.0      2964538
# 3           4  tt0071562     The Godfather Part II     9.0      1404866
# 4           5  tt0050083              12 Angry Men     9.0       902377
#
#    movieRank                        genres duration  seconds  \
# 0          0                     ['Drama']    2H22M   8520.0
# 1          0            ['Crime', 'Drama']    2H55M  10500.0
# 2          0  ['Action', 'Crime', 'Drama']    2H32M   9120.0
# 3          0            ['Crime', 'Drama']    3H22M  12120.0
# 4          0            ['Crime', 'Drama']    1H36M   5760.0
#
#                                          description  releaseYear  \
# 0  A banker convicted of uxoricide forms a friend...       1994.0
# ...

# %%
movies['suggestions']
# Out:
# 0      [['The Godfather', 'tt0068646', ['Crime', 'Dra...
# 1      [['The Godfather Part II', 'tt0071562', ['Crim...
# 2      [['The Dark Knight Rises', 'tt1345836', ['Acti...
# 3      [['The Godfather', 'tt0068646', ['Crime', 'Dra...
# 4      [["Schindler's List", 'tt0108052', ['Biography...
#                              ...
# 386    [['To the Forest of Firefly Lights', 'tt206170...
# 387    [['A Silent Voice: The Movie', 'tt5323662', ['...
# 388    [['Neeyat', 'tt21908676', ['Crime', 'Mystery',...
# 389    [['Shaitaan', 'tt27744786', ['Drama', 'Horror'...
# 390    [['Jawan', 'tt15354916', ['Action', 'Crime', '...
# Name: suggestions, Length: 641, dtype: object
