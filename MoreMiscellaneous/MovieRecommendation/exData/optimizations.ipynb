# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_parquet('movies.parquet')

# %%
movies
# Out:
#                id                          title releaseStatus userRate  \
# 1       tt0111161       The Shawshank Redemption          True     None
# 2       tt0068646                  The Godfather          True     None
# 3       tt0468569                The Dark Knight          True     None
# 4       tt0071562          The Godfather Part II          True     None
# 5       tt0050083                   12 Angry Men          True     None
# ...           ...                            ...           ...      ...
# 24125  tt29475625                      Prey 2024         False     None
# 24126  tt29657033       Perfect Marriage Revenge          True     None
# 24127   tt1740725  Bigfoot: The Lost Coast Tapes          True     None
# 24128   tt0075323  That's Entertainment, Part II          True     None
# 24129   tt0073600            Race with the Devil          True     None
#
#        runtimeSeconds  rating  ratingCount  \
# 1              8520.0     9.3      3006023
# ...

# %%
movies['id'] = movies['id'].apply(lambda x: x.strip('tt'))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33317 entries, 1 to 24129
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 33317 non-null  object
#  1   title              33317 non-null  object
#  2   releaseStatus      33299 non-null  object
#  3   userRate           0 non-null      object
#  4   runtimeSeconds     29853 non-null  float64
#  5   rating             30861 non-null  float64
#  6   ratingCount        33317 non-null  int64
#  7   genres             33317 non-null  object
#  8   description        31775 non-null  object
#  9   duration           29853 non-null  object
#  10  releaseYear        31700 non-null  float64
#  11  countriesOfOrigin  33002 non-null  object
#  12  directors          33317 non-null  object
#  13  writers            27056 non-null  object
#  14  cast               33317 non-null  object
#  15  suggestionsID      33313 non-null  object
# ...

# %%
movies['id'] = movies['id'].astype(np.int32)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33317 entries, 1 to 24129
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 33317 non-null  int32
#  1   title              33317 non-null  object
#  2   releaseStatus      33299 non-null  object
#  3   userRate           0 non-null      object
#  4   runtimeSeconds     29853 non-null  float64
#  5   rating             30861 non-null  float64
#  6   ratingCount        33317 non-null  int64
#  7   genres             33317 non-null  object
#  8   description        31775 non-null  object
#  9   duration           29853 non-null  object
#  10  releaseYear        31700 non-null  float64
#  11  countriesOfOrigin  33002 non-null  object
#  12  directors          33317 non-null  object
#  13  writers            27056 non-null  object
#  14  cast               33317 non-null  object
#  15  suggestionsID      33313 non-null  object
# ...

# %%
# Out:
# np.int64(35717988)
